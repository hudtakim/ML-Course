# %%
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
from sklearn import linear_model, preprocessing

data = pd.read_csv("car.data")

#label_encoder
le = preprocessing.LabelEncoder()

#The method fit_transform() takes a list (each of our columns) and will return to us an array containing our new values.
buying = le.fit_transform(list(data["buying"]))
maint = le.fit_transform(list(data["maint"]))
door = le.fit_transform(list(data["door"]))
persons = le.fit_transform(list(data["persons"]))
lug_boot = le.fit_transform(list(data["lug_boot"]))
safety = le.fit_transform(list(data["safety"]))
cls = le.fit_transform(list(data["class"]))

#Now we need to recombine our data into a feature list and a label list. We can use the zip() function to makes things easier.
x = list(zip(buying, maint, door, persons, lug_boot, safety)) #features
y = list(cls) #labels

#Finally we will split our data into training and testing data using the same process seen previously.
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.1)

#define model and k value
model = KNeighborsClassifier(n_neighbors=9)

#To train our model we follow precisely the same steps as outlined earlier.
model.fit(x_train, y_train)

#And once again to score our model we will do the following.
acc = model.score(x_test, y_test)
#print(acc)

#If we'd like to see how our model is performing on the unique elements of our test data we can do the following.
predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

for i in range(len(predicted)):
    print("Predicted: ", names[predicted[i]], "| Data: ", x_test[i], "| Actual: ", names[y_test[i]])
    
# This will display the predicted class, our data and the actual class
# We create a names list so that we can convert our integer predictions into their string representation 

    # Now we will we see the neighbors of each point in our testing data
    n = model.kneighbors([x_test[i]], 9, True)
    print("N: ", n)
# Out:
# Predicted:  good | Data:  (3, 3, 2, 2, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1316,  908, 1091,   91,  516, 1472, 1048,  777,  666]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 2, 0, 2, 1, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 405,  206,  911,  354,  188, 1383,  505,  685,  478]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 1, 0, 0, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1446,  145,   96, 1538,  826,  379,  597,  996, 1410]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 1, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 189,  859,  590,  508,  461, 1037, 1481, 1422,  596]],
#       dtype=int64))
# Predicted:  vgood | Data:  (1, 2, 2, 2, 0, 0) | Actual:  vgood
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 543,  473,  491,  407,  895, 1393,  760,  135, 1109]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 4, 0, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.73205081]]), array([[ 846,  409,  310,  626,  852,  607, 1295, 1054,  212]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 1, 2, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 457,  232, 1180, 1339,  124, 1252,  538,  630, 1037]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 0, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 295,  216, 1254,  504,  374,  463,  679,  498, 1143]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 0, 1, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1369,  367,  953,  728, 1138, 1541,  256,  784,  603]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 3, 2, 1, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1021,  140,  475,  562, 1242, 1318,  285, 1479,  763]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 2, 1, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 166,  763,  904, 1415,   11,  191,  790,  104,    5]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 1, 0, 2, 0, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 214,  949,  535, 1335,  606,  835, 1239, 1135,  838]],
#       dtype=int64))
# Predicted:  vgood | Data:  (1, 2, 2, 2, 1, 0) | Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1436,  323,  658, 1195,  695, 1109,  484,  811,   74]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 1, 2, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1272,  818, 1050,  230, 1243,  917, 1494,  329,  739]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1, 0, 0, 1, 2, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1328, 1541,  728, 1529, 1456,  376, 1457, 1407,  318]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 2, 0, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 939,   97,  724,   86,  922,  442, 1194, 1377,   65]],
#       dtype=int64))
# Predicted:  unacc | Data:  (2, 1, 3, 1, 2, 0) | Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1326,  177, 1043,  713,  639,  366,  485,  849,  756]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 1, 1, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 329,  837,  932,  363,  720, 1152,  426,  923,  597]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 0, 2, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 154,  575, 1551,  132,  275,  451, 1167, 1489,  546]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1, 0, 3, 1, 1, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1464, 1140, 1479,  599,  806,  747, 1524,  125,  291]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 4, 2, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.73205081]]), array([[1205,  961,  576,  386, 1440,  106,  852,  938,  342]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 1, 1, 2, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 314,  587, 1146,  181,    9,  934,  546, 1099,  245]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 2, 0, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1311,  183, 1544, 1548,    5, 1482,  995,  534,  859]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 3, 0, 2, 0, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 915, 1104,  647, 1019,  513,  514,  809, 1352,  433]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 0, 1, 0, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 444,  478,  578, 1335, 1491,  267,  103,  172, 1237]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 1, 2, 2, 0, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1381,  270,  775,  535,   16,  507,   34, 1083,   11]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1,
actual:  acc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 911,  960,  325,  323,  326,  753,  477, 1139,  372]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 1, 2, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1308,   98,  740,  388, 1303,  673,  162, 1013,  424]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 2, 1, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1455, 1465,  864,  168,  139, 1132,  337, 1219,  681]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 4, 2, 1, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.73205081, 1.73205081]]), array([[1440,  556,  825, 1205,  615,  518, 1498, 1054,  591]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 1, 1, 0, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 461, 1519, 1037,  437,  573,  688, 1323,  665, 1554]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 2, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1321, 1161, 1503,  595,   78, 1090, 1548, 1213,  859]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 1, 0, 0, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 722, 1424, 1284,  255,  509,  308,  771, 1257,  986]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 3, 0, 2, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[  28, 1365, 1016,  154,  460,  575,  410,  477,  321]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 0, 0, 0, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1427, 1098, 1424, 1320,  509,  402,  986,  466,  982]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 1, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 229, 1190,  196,  458,  440, 1261, 1097, 1125,  608]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 3, 1, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 912, 1130,   92,  516, 1472,  617,  489, 1049,  237]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1, 2, 3, 1, 2, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 418,  159,  277,  160,  874,   79,  697,  472, 1534]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 2, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1544, 1110,    5,  448, 1512,  239,  226,  962, 1241]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 0, 2, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 892,  548, 1335,  267,  278,  514, 1256, 1017,  405]],
#       dtype=int64))
# Predicted:  vgood | Data:  (2, 0, 3, 1, 1, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 366, 1202,  408, 1186,  660,  849, 1486, 1375,  223]],
#       dtype=int64))
# Predicted:  unacc | Data:  (3, 2, 3, 1, 0, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 900, 1049,  544, 1192,   13,  397, 1141, 1275,  854]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 3, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[   6, 1482, 1105, 1349,    5,  273, 1110,  281,  226]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 1, 0, 2, 1, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 694,   83,   73,  753, 1268,  540,  698,  326,  126]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 0, 0, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 905, 1098,  172, 1317,  707,  250, 1006,  466,  986]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 4, 1, 1, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 615,  518, 1498,  556, 1402,  626, 1440,  825, 1054]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 2, 2, 0, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1490, 1154, 1539,  484,  867, 1292, 1414, 1032,  775]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1, 3, 3, 1, 2, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 200, 1513,  569, 1280,  522,  210,  156, 1101, 1153]],
#       dtype=int64))
# Predicted:  vgood | Data:  (2, 0, 3, 2, 1, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1451,  591,  816,  129, 1093, 1202, 1053,  970,  762]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 3, 1, 2, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 494,  238, 1386,  645,  796, 1346, 1330, 1260,  388]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 2, 1, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 587, 1150, 1219,  663,  181, 1426, 1068,  724, 1455]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 3, 1, 2, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  36,  609, 1051,  266,  746, 1260, 1346,  817, 1322]],
#       dtype=int64))
# Predicted:  unacc | Data:  (2, 3, 2, 1, 1, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 511,  186, 1238,  714,   45,  662, 1348, 1155,  815]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 0, 1, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 651,  305, 1388,   93,  265, 1273,   89, 1044,  902]],
#       dtype=int64))
# Predicted:  acc | Data:  (1, 2, 1, 1, 2, 0) | Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 921, 1338, 1220,  373, 1162,  493,  526,  352,  973]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 1, 1, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1183, 1078, 1125, 1259,  618,   32,  101, 1185,  152]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 2, 2, 2, 1, 2) | Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1447, 1227,   18,  415,   16,  667, 1414,  113,  270]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 3, 0, 1, 2, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 884, 1080, 1551,  154,  456,  761,  642,  279, 1016]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 0, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 856, 1007, 1187, 1531, 1332,  102, 1532,  918, 1266]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 3, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1299,  786,  836, 1250,  797,  702, 1087,  610,  860]],
#       dtype=int64))
# Predicted:  acc | Data:  (1, 1, 2, 1, 1, 2) | Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 747, 1103, 1526, 1413, 1128,  545,  806, 1059, 1534]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 1, 2, 0, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1194,  258,  139, 1504,   77,  984, 1492, 1076, 1059]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 2, 2, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1243, 1211, 1027, 1396, 1272, 1048,  301,  908,  770]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 3, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1528,  737,  806, 1059,  306, 1524,  937,  866,  291]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 2, 0, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 183, 1384, 1492,  458, 1194,  939,  534,  754, 1219]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 3, 2, 0, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1373,  914,  568, 1258,  605,  549, 1153,  412,   87]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 3, 0, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 134,  506, 1399,  730,  550,  404, 1506, 1285,  237]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 0, 0, 2, 0, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[ 694,  540,  588, 1179, 1535,  727,  835, 1304, 1172]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 2, 1, 1, 1, 0) | Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 302,  880,  264,  950,  352, 1023, 1220, 1257,  372]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 3, 2, 0, 1, 0) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 605,  138,  357,  471,  296, 1184,  268, 1488,  914]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 2, 1, 2, 2) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1384,  723, 1492,  139, 1455,  423,  882, 1277,  924]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 2, 0, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 394,   65, 1077,  681,  827,  724, 1455, 1492, 1114]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 0, 1, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 676, 1173,  865,  647, 1007,  856,  915,  748, 1532]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 2, 2, 0, 1, 2) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1059,  205, 1300,  736, 1413,  785,  306,   87, 1337]],
#       dtype=int64))
# Predicted:  unacc | Data:  (2, 2, 0, 2, 1, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 483,  541,  410,  460, 1501,   44,  677,  326, 1012]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 0, 0, 0, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 824,  318,  977, 1143,  947,  295,  463,  402, 1216]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 1, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 116,  432, 1145,    9,  994, 1193, 1099, 1111,  364]],
#       dtype=int64))
# Predicted:  vgood | Data:  (2, 2, 2, 1, 1, 0) | Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 241, 1195,  375,  890,  345, 1234,  338, 1436, 1225]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 1, 3, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 866,   42,  621, 1309, 1040,  627, 1011, 1177,  962]],
#       dtype=int64))
# Predicted:  unacc | Data:  (3, 2, 3, 1, 2, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 397,  975, 1066,  692,  649,  756,  177, 1150,  587]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 0, 2, 0, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 835,  304, 1323, 1010,   19,  606, 1136,  873, 1554]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 4, 0, 1, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1402,  626,  563,  615,  137,  518, 1498, 1553,  310]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 3, 1, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1118,  380, 1228,  612,  151,  255,  722,  974,  169]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 2, 1, 2, 0, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[630, 583, 403, 433, 136, 858, 426, 123, 946]], dtype=int64))
# Predicted:  unacc | Data:  (1, 3, 1, 1, 0, 0) | Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 469, 1390,  764,  927,  974,  733,  255,  771, 1420]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 3, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1461,  406,  969,  876, 1049, 1141,  290,  898,   53]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 3, 0, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1309, 1084, 1069,   62, 1475,  627,  861,  121,  147]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1, 0, 3, 2, 2, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 129,  783,  634,  619, 1093, 1158,  203, 1047,  970]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 3, 1, 2, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1326,   79,  697, 1213,  236,  595, 1376,  204,  398]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 1, 3, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 258, 1169,  984, 1533,   10, 1313,  212,  712,  306]],
#       dtype=int64))
# Predicted:  unacc | Data:  (3, 1, 3, 2, 1, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1451, 1079,  332,  752,  445, 1240,  622,   69,  975]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 2, 0, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 116, 1122, 1497,  315,  833, 1065, 1193,  157,  765]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 3, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1461, 1444,  384,  487, 1049,  397,  692,   69, 1476]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 4, 2, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1054,  155, 1440,  556,  615,  576,  942,  409, 1498]],
#       dtype=int64))
# Predicted:  unacc | Data:  (0, 2, 3, 2, 0, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 667, 1291, 1069,  365, 1055, 1083,   16,  675,  941]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 0, 0, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1115,   89,  401,  300,  265,  529, 1347,  919, 1189]],
#       dtype=int64))
# Predicted:  unacc | Data:  (2, 0, 1, 1, 2, 0) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1124, 1283, 1265,  659, 1246, 1421, 1328, 1529,  440]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 3, 0, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1040,  180,  866,  488,  291,  962,  831,  430, 1215]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 2, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 659,  803,   26, 1015,  222,  534, 1366, 1186,  995]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 2, 2, 2, 2, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1156,  687, 1281,  956,  107,  246,  252, 1452, 1470]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 2, 1, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1345, 1444,  532,  601, 1374, 1416,  917, 1171, 1458]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 1, 3, 2, 1, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 333, 1468,  941,  530,  217, 1327,   15, 1546, 1242]],
#       dtype=int64))
# Predicted:  vgood | Data:  (1, 1, 3, 2, 1, 0) | Actual:  vgood
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1468, 1451, 1546,   74, 1486, 1134, 1109, 1093,  203]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 3, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 929,    4,  639,  797, 1326,  786, 1376,  937,   26]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 2, 3, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 159, 1549,  661,  931,  875,   79,  595, 1161,  501]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 1, 2, 2, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  41,  270,  820,  207, 1447, 1329,  925,  805,  217]],
#       dtype=int64))
# Predicted:  unacc | Data:  (1, 2, 0, 1, 1, 0) | Actual:  acc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1220,   44,  973, 1217, 1487,  343, 1358,  812,  372]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 1, 2, 2, 2, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1213, 1470, 1321,  236,  805,  798, 1378, 1540, 1329]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 3, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.41421356, 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[ 754,  639,  849, 1402,  223,  887,  634, 1301,   26]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 0, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 463, 1288,  728,  979, 1254,  376,  953,  758,  830]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 0, 1, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 295, 1179, 1135, 1254, 1535, 1415, 1157,  953, 1143]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 0, 1, 0, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1341, 1107, 1315,  488, 1200,  567,  981,  256,  872]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 3, 1, 2, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[882, 291, 204, 924, 697, 584, 430, 671, 691]], dtype=int64))
# Predicted:  good | Data:  (3, 1, 1, 0, 0, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1160,  744, 1514,  774,  648,  919, 1463,  401,   82]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 3, 1, 0, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 490,  978, 1500, 1359,   72, 1032, 1061, 1502, 1284]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 3, 2, 0, 2, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 112, 1399, 1210,  211, 1031,  184,  699,  412,  605]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 2, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 524, 1284,  441,  722,  612,   23, 1119,  182, 1084]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 1, 2, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[  19, 1172, 1481,  983, 1037,   43,  773, 1323,  289]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 0, 2, 1, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1455,  910, 1114,  957, 1132,  928,  636,  423, 1219]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 3, 1, 1, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1368,  988,  746, 1131, 1051, 1334, 1370, 1371,  620]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 1, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.41421356, 1.41421356, 1.41421356]]), array([[1547,  565, 1370,   30, 1085,   52, 1074, 1127, 1531]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 1, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[1273,  395,  265,   65, 1085, 1077,  566,  624,   46]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 2, 0, 2, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 383,  736,  954, 1450,   87,  690,  801,  559, 1076]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 1, 0, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 851,  219,   33,   58, 1159,  368, 1006, 1070,  172]],
#       dtype=int64))
# Predicted:  unacc | Data:  (3, 1, 1, 2, 1, 0) | Actual:  unacc
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[ 670,  622,  633,  739,  167, 1423,  128,  821,  909]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 3, 1, 1, 1, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 972,  771,  652, 1229,  469, 1013,  572,  308,  302]],
#       dtype=int64))
# Predicted:  unacc | Data:  (2, 3, 3, 1, 1, 2) | Actual:  unacc
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 176,  617, 1060,  434,  683,  489, 1389,  920,  780]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 3, 1, 1, 1, 2) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[1245,  601, 1007, 1416,  511, 1173, 1248, 1370,  988]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 0, 0, 1, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 982, 1257,  466,  372,  452,  812, 1449, 1098,  509]],
#       dtype=int64))
# Predicted:  good | Data:  (2, 0, 3, 0, 1, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1015,  223,  678,  792, 1301, 1105,  995,    4, 1482]],
#       dtype=int64))
# Predicted:  good | Data:  (1, 0, 3, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.41421356,
#         1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[1057,   26,  223,  634, 1129,  180,  995,  534, 1364]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 1, 2, 0, 0, 1) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.        , 1.41421356]]), array([[ 904,  164, 1177, 1274,  182,  346, 1550,  121, 1542]],
#       dtype=int64))
# Predicted:  good | Data:  (0, 2, 0, 1, 1, 1) | Actual:  good
# N:  (array([[1., 1., 1., 1., 1., 1., 1., 1., 1.]]), array([[1408, 1358, 1023, 1139,  478, 1491,  372,  735,  466]],
#       dtype=int64))
# Predicted:  good | Data:  (3, 1, 1, 0, 2, 0) | Actual:  good
# N:  (array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         1.        , 1.        , 1.41421356, 1.41421356]]), array([[ 100, 1269,  196,  922,   97,  229, 1527, 1310,  623]],
#       dtype=int64))
